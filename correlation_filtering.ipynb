# %% [markdown]
# # Import libraries

# %%
# python 3.7.4
import os, errno
import numpy as np # 1.17.2
import pandas as pd # 0.25.1

# %% [markdown]
# # Import data and categorize features

# %%
# Set the correlation coefficient threshold
THRES = 0.3
# Set Top n correlation coefficient to be selected
TOP = 10
# Outputs
OUTPUTS = ['TA4', 'TA5', 'KNO6', 'PEERW', 'PEERC', 'TASKM', 'TASKG']

# Create directory for output files
try:
    os.makedirs('results')
except OSError as e:
    if e.errno != errno.EEXIST:
        raise

try:
    os.makedirs('results_group')
except OSError as e:
    if e.errno != errno.EEXIST:
        raise

# Load data and make a copy
df = pd.read_csv('survey.csv')
df_copy = df.copy()

# Factorize all categorical features
df_copy = df_copy.apply(lambda x : pd.factorize(x)[0])

# Drop clomun ID
df_copy = df_copy.drop(columns=['ID'])

# %% [markdown]
# # Correlation coeffiecient between each feature and all outputs

# %%
# Iterate all outputs and calculate the correlation coefficient between each feature and each output
for label in OUTPUTS:
    corr = df_copy.corr(method='pearson', min_periods=1)[label]   
    # Drop out features with correlation coefficient < 0.3
    corr = corr[corr.abs() >= THRES]
    # Select Top 10 features
    corr_sorted = corr.reindex(corr.abs().sort_values(ascending=False).index).drop(labels=[label]).nlargest(TOP)
    # Save to csv file
    pd.DataFrame(corr_sorted).to_csv(path_or_buf='./results/'+label+'.csv')

# %% [markdown]
# # Correlation coeffiecient between each feature group and all outputs (Non linear regression model)

# %%
GROUPS = ['GP', 'TA', 'AGE', 'GEN', 'RACE', 'ETH', 'EDU', 'TIE', 'KNO', 'BFX', 'WEIP', 'PEER', 'TASK']

def non_linear_reg(group, output, threshold=THRES):
    # Copy the file to the other dataframe
    df1 = df_copy.copy()
    df1 = df1.iloc[:,0:-1]
    # Select features from the same group and drop any column if in the outputs
    df1 = df1.filter(regex=group+'[0-9]+')
    for out in OUTPUTS:
        if out in df1.columns:
            df1 = df1.drop([out], axis=1)
            
    # Copy another dataframe to iterate
    df2 = df1.copy()
    
    # Multiply each columns value to make a dataframe for the x1^2 and x1*x2 value
    for (name_1, data_1) in df2.iteritems():
        if name_1 not in OUTPUTS:
            for (name_2,data_2) in df2.iteritems():
                if name_2 not in OUTPUTS:
                    if (df2.columns.get_loc(str(name_2))) >= (df2.columns.get_loc(str(name_1))):
                        df1[str(name_1)+'*' +str(name_2)] = data_1*data_2

    # Append the output column
    df1 = df1.join(df_copy[output])

    # Calculate correlation coeeficients
    df2 = df1.copy()
    columns = []
    corr = []
    for (name, data) in df2.iteritems():
        columns.append(name)
        corr.append(df2[str(name)].corr(df2[output]))
    corr = np.array(corr).reshape(1,len(corr))

    # Build the correlation dataframe
    corr_df = pd.DataFrame(np.array(corr),columns=columns)
    print("The correlation dataframe between group " + group + ' and output ' + output)
    print(corr_df)

#     # Filter features according to the threshold
#     drop_name = []
#     for (name, data) in corr_df.iteritems():
#         if np.abs(data.values) < threshold:
#             drop_name.append(name)
#     df_filtered = df2.drop(columns=drop_name)
    
    corr_df.to_csv('./results_group/'+group+'_'+output+'_corr.csv')
# #     Filter correlations according to the threshold
#     corr_df_filtered = corr_df.drop(columns=drop_name)

# #     Print data (including x^2 and x1*x2 items) filtered by correlation coeeficients threshold
#     print("There are " + str(df_filtered.shape[1]) + " columns left with "+str(threshold) + " threshold")
#     print("Filtered results:")
#     print(df_filtered)
#     df_filtered.to_csv('./results_group/group_'+group+'_'+output+'.csv')

# %%
# Analyze each group with each output
for group in GROUPS:
    for out in OUTPUTS:
        non_linear_reg(group, out)
# Out:
# The correlation dataframe between group GP and output TA4
#         GP1       GP2       GP3       GP4       GP5       GP6       GP7  \
# 0  0.415516  0.415516  0.164448  0.495126  0.348865  0.297683 -0.052382
#
#         GP8   GP1*GP1   GP1*GP2  ...   GP5*GP6   GP5*GP7   GP5*GP8   GP6*GP6  \
# 0  0.091287  0.451511  0.451511  ...  0.304692  0.189948  0.299943  0.409091
#
#     GP6*GP7   GP6*GP8   GP7*GP7   GP7*GP8   GP8*GP8  TA4
# 0  0.241475  0.071495 -0.096825  0.012783  0.091287  1.0
#
# [1 rows x 45 columns]
# The correlation dataframe between group GP and output TA5
#         GP1       GP2      GP3       GP4       GP5       GP6      GP7  \
# 0  0.084921  0.084921  0.10008  0.070261 -0.016024  0.179277  0.62695
#
#         GP8   GP1*GP1   GP1*GP2  ...   GP5*GP6   GP5*GP7   GP5*GP8   GP6*GP6  \
# 0 -0.111111  0.108226  0.108226  ...  0.161324  0.191059 -0.190476  0.148605
#
#     GP6*GP7   GP6*GP8   GP7*GP7   GP7*GP8   GP8*GP8  TA5
# 0  0.390735 -0.032855  0.608898  0.054455 -0.111111  1.0
#
# [1 rows x 45 columns]
# The correlation dataframe between group GP and output KNO6
#         GP1       GP2       GP3       GP4       GP5       GP6       GP7  \
# 0  0.594618  0.594618  0.309161  0.327413  0.283537  0.533408 -0.007386
#
#         GP8   GP1*GP1   GP1*GP2  ...   GP5*GP6   GP5*GP7   GP5*GP8   GP6*GP6  \
# 0 -0.141585  0.508175  0.508175  ...  0.331231  0.205332  0.106649  0.483158
#
#     GP6*GP7   GP6*GP8  GP7*GP7   GP7*GP8   GP8*GP8  KNO6
# 0  0.332426 -0.081469 -0.12287 -0.146892 -0.141585   1.0
#
# [1 rows x 45 columns]
# The correlation dataframe between group GP and output PEERW
#         GP1       GP2       GP3       GP4       GP5       GP6       GP7  \
# 0  0.388877  0.388877  0.198077  0.325342  0.043839  0.417438 -0.091548
#
#         GP8  GP1*GP1  GP1*GP2  ...  GP5*GP6   GP5*GP7   GP5*GP8   GP6*GP6  \
# 0  0.271653  0.34157  0.34157  ...  0.36153 -0.109162  0.243933  0.352154
#
#     GP6*GP7  GP6*GP8   GP7*GP7  GP7*GP8   GP8*GP8  PEERW
# 0  0.298699   0.3548 -0.173793   0.1114  0.271653    1.0
#
# [1 rows x 45 columns]
# The correlation dataframe between group GP and output PEERC
#         GP1       GP2      GP3       GP4       GP5       GP6       GP7  \
# 0  0.143778  0.143778  0.14758  0.165915  0.296343  0.176244  0.141027
#
#         GP8   GP1*GP1   GP1*GP2  ...  GP5*GP6   GP5*GP7   GP5*GP8   GP6*GP6  \
# 0 -0.027308 -0.016986 -0.016986  ...  0.20599  0.281739  0.011703 -0.000809
#
#     GP6*GP7   GP6*GP8   GP7*GP7   GP7*GP8   GP8*GP8  PEERC
# 0  0.093749  0.011567  0.028964 -0.110892 -0.027308    1.0
#
# [1 rows x 45 columns]
# The correlation dataframe between group GP and output TASKM
#         GP1       GP2       GP3       GP4       GP5       GP6       GP7  \
# 0  0.148842  0.148842  0.323415 -0.020234 -0.072406  0.155043  0.017461
#
#         GP8   GP1*GP1   GP1*GP2  ...   GP5*GP6   GP5*GP7   GP5*GP8   GP6*GP6  \
# 0  0.136931  0.015225  0.015225  ... -0.088361 -0.050125  0.052164  0.013528
#
#    GP6*GP7  GP6*GP8  GP7*GP7   GP7*GP8   GP8*GP8  TASKM
# 0  0.14689  0.25461 -0.06455  0.166176  0.136931    1.0
#
# [1 rows x 45 columns]
# The correlation dataframe between group GP and output TASKG
#         GP1       GP2       GP3       GP4       GP5       GP6       GP7  \
# 0  0.223591  0.223591  0.304776  0.123044 -0.331667  0.210121  0.273041
#
#         GP8   GP1*GP1   GP1*GP2  ...   GP5*GP6   GP5*GP7   GP5*GP8   GP6*GP6  \
# 0 -0.079305  0.192655  0.192655  ... -0.230288 -0.210854 -0.147281  0.192271
#
#     GP6*GP7   GP6*GP8   GP7*GP7   GP7*GP8   GP8*GP8  TASKG
# 0  0.422589 -0.090631  0.252347 -0.038867 -0.079305    1.0
#
# [1 rows x 45 columns]
# The correlation dataframe between group TA and output TA4
#         TA1       TA2       TA3      TA6      TA7   TA1*TA1   TA1*TA2  \
# 0  0.213655  0.146385  0.345797 -0.27404 -0.01575  0.187742  0.344355
#
#     TA1*TA3   TA1*TA6   TA1*TA7  ...   TA2*TA3   TA2*TA6   TA2*TA7   TA3*TA3  \
# 0  0.267976 -0.177004  0.036598  ...  0.169886 -0.167432 -0.186986  0.406332
#
#     TA3*TA6   TA3*TA7   TA6*TA6  TA6*TA7   TA7*TA7  TA4
# 0 -0.049162  0.211373 -0.156766 -0.20751 -0.026863  1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group TA and output TA5
#         TA1       TA2       TA3      TA6       TA7   TA1*TA1   TA1*TA2  \
# 0  0.026672  0.259837 -0.267104 -0.15114 -0.170938  0.012352  0.129251
#
#     TA1*TA3   TA1*TA6   TA1*TA7  ...   TA2*TA3   TA2*TA6   TA2*TA7   TA3*TA3  \
# 0 -0.245356 -0.114956 -0.157558  ... -0.075927 -0.074521  0.014527 -0.263616
#
#     TA3*TA6   TA3*TA7   TA6*TA6   TA6*TA7  TA7*TA7  TA5
# 0 -0.181385 -0.264917 -0.125591 -0.022961  -0.1482  1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group TA and output KNO6
#         TA1       TA2      TA3       TA6       TA7   TA1*TA1   TA1*TA2  \
# 0  0.493588  0.086001  0.06751  0.112296  0.108818  0.559478  0.399767
#
#     TA1*TA3   TA1*TA6   TA1*TA7  ...   TA2*TA3   TA2*TA6   TA2*TA7   TA3*TA3  \
# 0  0.308516  0.275834  0.369721  ... -0.112658  0.071087 -0.099289  0.178003
#
#     TA3*TA6  TA3*TA7   TA6*TA6   TA6*TA7   TA7*TA7  KNO6
# 0  0.021229  0.29464  0.062944 -0.095756  0.219353   1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group TA and output PEERW
#         TA1       TA2       TA3       TA6       TA7   TA1*TA1   TA1*TA2  \
# 0  0.121104  0.423513 -0.089835  0.016585 -0.083324  0.225056  0.356192
#
#     TA1*TA3   TA1*TA6   TA1*TA7  ...   TA2*TA3   TA2*TA6   TA2*TA7   TA3*TA3  \
# 0  0.002712 -0.042303  0.074526  ... -0.001505  0.217163 -0.053839 -0.058485
#
#     TA3*TA6   TA3*TA7   TA6*TA6   TA6*TA7   TA7*TA7  PEERW
# 0 -0.219446 -0.068505  0.177109 -0.124304 -0.003641    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group TA and output PEERC
#         TA1           TA2      TA3      TA6       TA7   TA1*TA1   TA1*TA2  \
# 0  0.059816 -3.241095e-17 -0.06233  0.39622  0.317244  0.067546 -0.103534
#
#     TA1*TA3   TA1*TA6  TA1*TA7  ...   TA2*TA3   TA2*TA6   TA2*TA7   TA3*TA3  \
# 0 -0.057617  0.373805  0.16807  ...  0.126256  0.221835  0.408207 -0.216727
#
#     TA3*TA6   TA3*TA7   TA6*TA6   TA6*TA7   TA7*TA7  PEERC
# 0  0.329976 -0.022851  0.295659  0.474026  0.266229    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group TA and output TASKM
#         TA1      TA2       TA3       TA6       TA7   TA1*TA1   TA1*TA2  \
# 0 -0.221872  0.09759 -0.004433  0.576625 -0.007875 -0.306984 -0.304151
#
#     TA1*TA3   TA1*TA6   TA1*TA7  ...   TA2*TA3   TA2*TA6   TA2*TA7  TA3*TA3  \
# 0 -0.051442  0.294566 -0.100305  ...  0.045126  0.428576  0.055698   0.0115
#
#     TA3*TA6   TA3*TA7   TA6*TA6   TA6*TA7   TA7*TA7  TASKM
# 0  0.098324 -0.035578  0.497241  0.108471 -0.060149    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group TA and output TASKG
#         TA1       TA2       TA3       TA6       TA7   TA1*TA1   TA1*TA2  \
# 0 -0.078528  0.339123 -0.146353  0.163673 -0.123147 -0.077142  0.034927
#
#     TA1*TA3   TA1*TA6   TA1*TA7  ...   TA2*TA3  TA2*TA6   TA2*TA7   TA3*TA3  \
# 0 -0.092498 -0.024098 -0.125998  ... -0.112997  0.17802 -0.019009 -0.042182
#
#     TA3*TA6   TA3*TA7   TA6*TA6   TA6*TA7   TA7*TA7  TASKG
# 0 -0.064064 -0.024544  0.152149 -0.053263 -0.067982    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group AGE and output TA4
#       AGE1      AGE2      AGE3  AGE1*AGE1  AGE1*AGE2  AGE1*AGE3  AGE2*AGE2  \
# 0  0.20795  0.265619  0.029715   0.029029   0.228456   0.051459   0.280825
#
#    AGE2*AGE3  AGE3*AGE3  TA4
# 0   0.158313    0.04964  1.0
# The correlation dataframe between group AGE and output TA5
#        AGE1      AGE2     AGE3  AGE1*AGE1  AGE1*AGE2  AGE1*AGE3  AGE2*AGE2  \
# 0  0.075142 -0.227147 -0.08816  -0.001472  -0.111791  -0.051543  -0.168531
#
#    AGE2*AGE3  AGE3*AGE3  TA5
# 0  -0.076913  -0.041375  1.0
# The correlation dataframe between group AGE and output KNO6
#        AGE1      AGE2     AGE3  AGE1*AGE1  AGE1*AGE2  AGE1*AGE3  AGE2*AGE2  \
# 0  0.345435  0.184355 -0.15031   0.193399   0.238979   0.059406   0.177999
#
#    AGE2*AGE3  AGE3*AGE3  KNO6
# 0  -0.242435  -0.141353   1.0
# The correlation dataframe between group AGE and output PEERW
#        AGE1      AGE2      AGE3  AGE1*AGE1  AGE1*AGE2  AGE1*AGE3  AGE2*AGE2  \
# 0 -0.084719  0.189496 -0.110797  -0.096669  -0.050966  -0.186554   0.165933
#
#    AGE2*AGE3  AGE3*AGE3  PEERW
# 0   0.123195  -0.133383    1.0
# The correlation dataframe between group AGE and output PEERC
#        AGE1      AGE2      AGE3  AGE1*AGE1  AGE1*AGE2  AGE1*AGE3  AGE2*AGE2  \
# 0  0.450997  0.127406  0.370008    0.41393   0.193016   0.397024   0.104749
#
#    AGE2*AGE3  AGE3*AGE3  PEERC
# 0   0.175844   0.314258    1.0
# The correlation dataframe between group AGE and output TASKM
#       AGE1      AGE2      AGE3  AGE1*AGE1  AGE1*AGE2  AGE1*AGE3  AGE2*AGE2  \
# 0  0.33142 -0.107622  0.191293   0.171756   0.044765   0.159737  -0.108777
#
#    AGE2*AGE3  AGE3*AGE3  TASKM
# 0   0.079157   0.125989    1.0
# The correlation dataframe between group AGE and output TASKG
#        AGE1      AGE2      AGE3  AGE1*AGE1  AGE1*AGE2  AGE1*AGE3  AGE2*AGE2  \
# 0  0.242756  0.077582  0.038723    0.27951   0.257474   0.150879  -0.008659
#
#    AGE2*AGE3  AGE3*AGE3  TASKG
# 0   0.098852   -0.03375    1.0
# The correlation dataframe between group GEN and output TA4
#        GEN1      GEN2      GEN3  GEN1*GEN1  GEN1*GEN2  GEN1*GEN3  GEN2*GEN2  \
# 0 -0.242241 -0.283311  0.058202  -0.242241  -0.255699  -0.063558  -0.257922
#
#    GEN2*GEN3  GEN3*GEN3  TA4
# 0  -0.057378   0.073699  1.0
# The correlation dataframe between group GEN and output TA5
#        GEN1      GEN2      GEN3  GEN1*GEN1  GEN1*GEN2  GEN1*GEN3  GEN2*GEN2  \
# 0  0.272166 -0.021552  0.078891   0.272166    0.03257   0.109133  -0.069224
#
#    GEN2*GEN3  GEN3*GEN3  TA5
# 0  -0.030554  -0.070977  1.0
# The correlation dataframe between group GEN and output KNO6
#        GEN1      GEN2      GEN3  GEN1*GEN1  GEN1*GEN2  GEN1*GEN3  GEN2*GEN2  \
# 0  0.176033 -0.039947  0.136898   0.176033  -0.065399   0.098257  -0.112982
#
#    GEN2*GEN3  GEN3*GEN3  KNO6
# 0  -0.066744   0.175102   1.0
# The correlation dataframe between group GEN and output PEERW
#        GEN1      GEN2      GEN3  GEN1*GEN1  GEN1*GEN2  GEN1*GEN3  GEN2*GEN2  \
# 0  0.047529  0.227194 -0.190067   0.047529   0.179484  -0.127698   0.264466
#
#    GEN2*GEN3  GEN3*GEN3  PEERW
# 0  -0.004065   -0.23681    1.0
# The correlation dataframe between group GEN and output PEERC
#        GEN1      GEN2      GEN3  GEN1*GEN1  GEN1*GEN2  GEN1*GEN3  GEN2*GEN2  \
# 0  0.052955  0.184909  0.076765   0.052955   0.070264  -0.059754   0.185086
#
#    GEN2*GEN3  GEN3*GEN3  PEERC
# 0   0.051492  -0.042161    1.0
# The correlation dataframe between group GEN and output TASKM
#        GEN1      GEN2     GEN3  GEN1*GEN1  GEN1*GEN2  GEN1*GEN3  GEN2*GEN2  \
# 0  0.158388  0.003219 -0.02381   0.158388  -0.023786    0.00227  -0.074624
#
#    GEN2*GEN3  GEN3*GEN3  TASKM
# 0  -0.039447  -0.042928    1.0
# The correlation dataframe between group GEN and output TASKG
#        GEN1      GEN2      GEN3  GEN1*GEN1  GEN1*GEN2  GEN1*GEN3  GEN2*GEN2  \
# 0  0.089035 -0.075516  0.190759   0.089035   0.080073   0.065075   0.038394
#
#    GEN2*GEN3  GEN3*GEN3  TASKG
# 0   0.087231   0.135642    1.0
# The correlation dataframe between group RACE and output TA4
#       RACE1     RACE2     RACE3  RACE1*RACE1  RACE1*RACE2  RACE1*RACE3  \
# 0  0.401597  0.123487  0.158992     0.422203     0.321388     0.340364
#
#    RACE2*RACE2  RACE2*RACE3  RACE3*RACE3  TA4
# 0       0.1406     0.188132     0.130943  1.0
# The correlation dataframe between group RACE and output TA5
#       RACE1     RACE2     RACE3  RACE1*RACE1  RACE1*RACE2  RACE1*RACE3  \
# 0  0.037192  0.123463  0.318134      0.21875     0.185932     0.270945
#
#    RACE2*RACE2  RACE2*RACE3  RACE3*RACE3  TA5
# 0      0.13951     0.239477     0.286687  1.0
# The correlation dataframe between group RACE and output KNO6
#       RACE1     RACE2    RACE3  RACE1*RACE1  RACE1*RACE2  RACE1*RACE3  \
# 0  0.192032  0.166653 -0.14062     0.043441     0.036924    -0.001285
#
#    RACE2*RACE2  RACE2*RACE3  RACE3*RACE3  KNO6
# 0     0.168077    -0.031804    -0.218402   1.0
# The correlation dataframe between group RACE and output PEERW
#       RACE1     RACE2    RACE3  RACE1*RACE1  RACE1*RACE2  RACE1*RACE3  \
# 0  0.153405  0.190819  0.39052     0.255483     0.176547     0.333959
#
#    RACE2*RACE2  RACE2*RACE3  RACE3*RACE3  PEERW
# 0     0.225224     0.280411     0.343952    1.0
# The correlation dataframe between group RACE and output PEERC
#       RACE1     RACE2     RACE3  RACE1*RACE1  RACE1*RACE2  RACE1*RACE3  \
# 0 -0.075737  0.138085  0.216908    -0.104111    -0.052224    -0.043636
#
#    RACE2*RACE2  RACE2*RACE3  RACE3*RACE3  PEERC
# 0     0.086861      0.07322     0.155249    1.0
# The correlation dataframe between group RACE and output TASKM
#       RACE1     RACE2     RACE3  RACE1*RACE1  RACE1*RACE2  RACE1*RACE3  \
# 0 -0.323024  0.238153  0.067451    -0.302388    -0.047613    -0.133715
#
#    RACE2*RACE2  RACE2*RACE3  RACE3*RACE3  TASKM
# 0     0.235352      0.16794     0.086231    1.0
# The correlation dataframe between group RACE and output TASKG
#       RACE1     RACE2     RACE3  RACE1*RACE1  RACE1*RACE2  RACE1*RACE3  \
# 0 -0.197196  0.416342  0.416464     0.079305     0.263693     0.285129
#
#    RACE2*RACE2  RACE2*RACE3  RACE3*RACE3  TASKG
# 0     0.459373     0.506147     0.481382    1.0
# The correlation dataframe between group ETH and output TA4
#        ETH1      ETH2      ETH3  ETH1*ETH1  ETH1*ETH2  ETH1*ETH3  ETH2*ETH2  \
# 0  0.058172  0.228931  0.086077   0.111193   0.383693   0.055028   0.244961
#
#    ETH2*ETH3  ETH3*ETH3  TA4
# 0   0.142532  -0.020289  1.0
# The correlation dataframe between group ETH and output TA5
#        ETH1      ETH2      ETH3  ETH1*ETH1  ETH1*ETH2  ETH1*ETH3  ETH2*ETH2  \
# 0  0.165632  0.051841  0.223259   0.163143  -0.064262   0.138548  -0.125572
#
#    ETH2*ETH3  ETH3*ETH3  TA5
# 0   0.032867    0.13966  1.0
# The correlation dataframe between group ETH and output KNO6
#        ETH1      ETH2      ETH3  ETH1*ETH1  ETH1*ETH2  ETH1*ETH3  ETH2*ETH2  \
# 0  0.332628  0.096086  0.110387   0.281912   0.184007   0.228639   0.215118
#
#    ETH2*ETH3  ETH3*ETH3  KNO6
# 0   0.043255    0.13515   1.0
# The correlation dataframe between group ETH and output PEERW
#        ETH1      ETH2      ETH3  ETH1*ETH1  ETH1*ETH2  ETH1*ETH3  ETH2*ETH2  \
# 0  0.295727 -0.226707  0.189643    0.26399      0.011   0.441991  -0.267688
#
#    ETH2*ETH3  ETH3*ETH3  PEERW
# 0  -0.200871   0.165471    1.0
# The correlation dataframe between group ETH and output PEERC
#        ETH1      ETH2      ETH3  ETH1*ETH1  ETH1*ETH2  ETH1*ETH3  ETH2*ETH2  \
# 0  0.236476  0.195892  0.451837   0.041949  -0.063488   0.381862   0.080879
#
#    ETH2*ETH3  ETH3*ETH3  PEERC
# 0    0.34826   0.472502    1.0
# The correlation dataframe between group ETH and output TASKM
#       ETH1      ETH2      ETH3  ETH1*ETH1  ETH1*ETH2  ETH1*ETH3  ETH2*ETH2  \
# 0  0.32514  0.074536 -0.141412   0.210849   0.082071  -0.075664   0.130104
#
#    ETH2*ETH3  ETH3*ETH3  TASKM
# 0    0.13251  -0.075947    1.0
# The correlation dataframe between group ETH and output TASKG
#        ETH1      ETH2      ETH3  ETH1*ETH1  ETH1*ETH2  ETH1*ETH3  ETH2*ETH2  \
# 0  0.513488  0.101754 -0.350749   0.497725   0.380788   0.005205   0.043268
#
#    ETH2*ETH3  ETH3*ETH3  TASKG
# 0  -0.140753  -0.390868    1.0
# The correlation dataframe between group EDU and output TA4
#        EDU4      EDU1      EDU2      EDU3  EDU4*EDU4  EDU4*EDU1  EDU4*EDU2  \
# 0 -0.119523  0.220193 -0.452506 -0.314088  -0.181514  -0.100767  -0.344896
#
#    EDU4*EDU3  EDU1*EDU1  EDU1*EDU2  EDU1*EDU3  EDU2*EDU2  EDU2*EDU3  \
# 0   -0.27007    0.23559   -0.17734  -0.098064   -0.44837   -0.40331
#
#    EDU3*EDU3  TA4
# 0  -0.341333  1.0
# The correlation dataframe between group EDU and output TA5
#        EDU4      EDU1      EDU2      EDU3  EDU4*EDU4  EDU4*EDU1  EDU4*EDU2  \
# 0 -0.090924 -0.274796  0.137693  0.192641   -0.14326  -0.195656  -0.080521
#
#    EDU4*EDU3  EDU1*EDU1  EDU1*EDU2  EDU1*EDU3  EDU2*EDU2  EDU2*EDU3  \
# 0  -0.026691   -0.20538  -0.046733  -0.093309   0.124773   0.127117
#
#    EDU3*EDU3  TA5
# 0   0.132067  1.0
# The correlation dataframe between group EDU and output KNO6
#        EDU4      EDU1      EDU2     EDU3  EDU4*EDU4  EDU4*EDU1  EDU4*EDU2  \
# 0  0.084263  0.070347  0.385043  0.03702   0.054386   0.144787   0.186136
#
#    EDU4*EDU3  EDU1*EDU1  EDU1*EDU2  EDU1*EDU3  EDU2*EDU2  EDU2*EDU3  \
# 0  -0.069813   0.039186   0.173598  -0.097501   0.359596   0.206768
#
#    EDU3*EDU3  KNO6
# 0  -0.022216   1.0
# The correlation dataframe between group EDU and output PEERW
#        EDU4      EDU1      EDU2      EDU3  EDU4*EDU4  EDU4*EDU1  EDU4*EDU2  \
# 0  0.084685  0.154433 -0.288178  0.018429   0.077968   0.055077  -0.278705
#
#    EDU4*EDU3  EDU1*EDU1  EDU1*EDU2  EDU1*EDU3  EDU2*EDU2  EDU2*EDU3  \
# 0    0.03827   0.136847  -0.158836    0.10571  -0.249733  -0.227581
#
#    EDU3*EDU3  PEERW
# 0  -0.042889    1.0
# The correlation dataframe between group EDU and output PEERC
#       EDU4      EDU1      EDU2      EDU3  EDU4*EDU4  EDU4*EDU1  EDU4*EDU2  \
# 0  0.49162  0.397298  0.340769  0.320774   0.552315   0.590671   0.381561
#
#    EDU4*EDU3  EDU1*EDU1  EDU1*EDU2  EDU1*EDU3  EDU2*EDU2  EDU2*EDU3  \
# 0   0.400839   0.320454   0.473641   0.453177   0.309378   0.205445
#
#    EDU3*EDU3  PEERC
# 0   0.261672    1.0
# The correlation dataframe between group EDU and output TASKM
#        EDU4     EDU1    EDU2      EDU3  EDU4*EDU4  EDU4*EDU1  EDU4*EDU2  \
# 0  0.089642  0.09616  0.2473  0.431871   0.093593   0.005598   0.117443
#
#    EDU4*EDU3  EDU1*EDU1  EDU1*EDU2  EDU1*EDU3  EDU2*EDU2  EDU2*EDU3  \
# 0    0.22275    0.00832   0.064063   0.188344   0.235681   0.375877
#
#    EDU3*EDU3  TASKM
# 0   0.398222    1.0
# The correlation dataframe between group EDU and output TASKG
#        EDU4      EDU1      EDU2      EDU3  EDU4*EDU4  EDU4*EDU1  EDU4*EDU2  \
# 0  0.077876 -0.215506 -0.052567  0.486036   0.046814  -0.086151  -0.023247
#
#    EDU4*EDU3  EDU1*EDU1  EDU1*EDU2  EDU1*EDU3  EDU2*EDU2  EDU2*EDU3  \
# 0   0.359954  -0.278216  -0.107623   0.242392  -0.007907   0.319015
#
#    EDU3*EDU3  TASKG
# 0   0.504769    1.0
# The correlation dataframe between group TIE and output TA4
#       TIE1      TIE2      TIE3      TIE4  TIE1*TIE1  TIE1*TIE2  TIE1*TIE3  \
# 0 -0.02336  0.154089  0.014614  0.007015   0.037182  -0.110119   0.098312
#
#    TIE1*TIE4  TIE2*TIE2  TIE2*TIE3  TIE2*TIE4  TIE3*TIE3  TIE3*TIE4  \
# 0   0.182036   0.186917  -0.156158   0.061045   0.075957  -0.033625
#
#    TIE4*TIE4  TA4
# 0  -0.114436  1.0
# The correlation dataframe between group TIE and output TA5
#        TIE1      TIE2      TIE3      TIE4  TIE1*TIE1  TIE1*TIE2  TIE1*TIE3  \
# 0  0.015994  0.320059 -0.132293  0.099261   0.054685   0.051144  -0.037489
#
#    TIE1*TIE4  TIE2*TIE2  TIE2*TIE3  TIE2*TIE4  TIE3*TIE3  TIE3*TIE4  \
# 0   0.008522   0.306371   0.019416   0.146071  -0.156105  -0.027508
#
#    TIE4*TIE4  TA5
# 0    0.07701  1.0
# The correlation dataframe between group TIE and output KNO6
#        TIE1      TIE2      TIE3      TIE4  TIE1*TIE1  TIE1*TIE2  TIE1*TIE3  \
# 0 -0.011528  0.179951  0.302124  0.332348  -0.034077   0.222482   0.097208
#
#    TIE1*TIE4  TIE2*TIE2  TIE2*TIE3  TIE2*TIE4  TIE3*TIE3  TIE3*TIE4  \
# 0  -0.006417   0.122141   0.334889   0.221834   0.359843   0.286134
#
#    TIE4*TIE4  KNO6
# 0   0.287024   1.0
# The correlation dataframe between group TIE and output PEERW
#        TIE1      TIE2      TIE3      TIE4  TIE1*TIE1  TIE1*TIE2  TIE1*TIE3  \
# 0  0.357095  0.224997  0.056172 -0.086734   0.414044   0.324614   0.320243
#
#    TIE1*TIE4  TIE2*TIE2  TIE2*TIE3  TIE2*TIE4  TIE3*TIE3  TIE3*TIE4  \
# 0   0.063497   0.285125   0.257689   0.188933  -0.002435  -0.113183
#
#    TIE4*TIE4  PEERW
# 0  -0.150468    1.0
# The correlation dataframe between group TIE and output PEERC
#       TIE1      TIE2      TIE3      TIE4  TIE1*TIE1  TIE1*TIE2  TIE1*TIE3  \
# 0  0.06726  0.346709  0.146448  0.343109   0.052832   0.237957   0.023825
#
#    TIE1*TIE4  TIE2*TIE2  TIE2*TIE3  TIE2*TIE4  TIE3*TIE3  TIE3*TIE4  \
# 0   -0.01885   0.316692   0.330007   0.391784   0.069608   0.192349
#
#    TIE4*TIE4  PEERC
# 0   0.375243    1.0
# The correlation dataframe between group TIE and output TASKM
#       TIE1      TIE2      TIE3      TIE4  TIE1*TIE1  TIE1*TIE2  TIE1*TIE3  \
# 0  0.01752 -0.073695  0.062108  0.003508  -0.006197  -0.294135   0.086489
#
#    TIE1*TIE4  TIE2*TIE2  TIE2*TIE3  TIE2*TIE4  TIE3*TIE3  TIE3*TIE4  \
# 0  -0.024505   -0.10681  -0.166233   0.002775   0.065106  -0.009922
#
#    TIE4*TIE4  TASKM
# 0  -0.006602    1.0
# The correlation dataframe between group TIE and output TASKG
#        TIE1      TIE2      TIE3      TIE4  TIE1*TIE1  TIE1*TIE2  TIE1*TIE3  \
# 0  0.020294 -0.323019 -0.107913 -0.272724  -0.010767  -0.313431   0.017298
#
#    TIE1*TIE4  TIE2*TIE2  TIE2*TIE3  TIE2*TIE4  TIE3*TIE3  TIE3*TIE4  \
# 0   -0.30108  -0.268136  -0.353012  -0.321209  -0.110503  -0.337126
#
#    TIE4*TIE4  TASKG
# 0  -0.287733    1.0
# The correlation dataframe between group KNO and output TA4
#        KNO1      KNO2     KNO3      KNO4      KNO5  KNO1*KNO1  KNO1*KNO2  \
# 0  0.196932 -0.136931 -0.14198  0.446778  0.193744   0.196932  -0.136931
#
#    KNO1*KNO3  KNO1*KNO4  KNO1*KNO5  ...  KNO2*KNO3  KNO2*KNO4  KNO2*KNO5  \
# 0  -0.130693   0.486345   0.352301  ...  -0.136931        NaN  -0.136931
#
#    KNO3*KNO3  KNO3*KNO4  KNO3*KNO5  KNO4*KNO4  KNO4*KNO5  KNO5*KNO5  TA4
# 0  -0.209139   0.386036  -0.047655   0.429644    0.30482   0.221371  1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group KNO and output TA5
#        KNO1      KNO2     KNO3      KNO4      KNO5  KNO1*KNO1  KNO1*KNO2  \
# 0 -0.059924 -0.305556 -0.00149 -0.167813  0.171336  -0.059924  -0.305556
#
#    KNO1*KNO3  KNO1*KNO4  KNO1*KNO5  ...  KNO2*KNO3  KNO2*KNO4  KNO2*KNO5  \
# 0  -0.092793  -0.042283   0.204979  ...  -0.305556        NaN  -0.305556
#
#    KNO3*KNO3  KNO3*KNO4  KNO3*KNO5  KNO4*KNO4  KNO4*KNO5  KNO5*KNO5  TA5
# 0  -0.049691  -0.234599  -0.051413  -0.262687  -0.051273    0.15458  1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group KNO and output KNO6
#        KNO1      KNO2      KNO3      KNO4      KNO5  KNO1*KNO1  KNO1*KNO2  \
# 0 -0.205729 -0.003218  0.100785  0.624046  0.146833  -0.205729  -0.003218
#
#    KNO1*KNO3  KNO1*KNO4  KNO1*KNO5  ...  KNO2*KNO3  KNO2*KNO4  KNO2*KNO5  \
# 0  -0.137865    0.17334  -0.384291  ...  -0.003218        NaN  -0.003218
#
#    KNO3*KNO3  KNO3*KNO4  KNO3*KNO5  KNO4*KNO4  KNO4*KNO5  KNO5*KNO5  KNO6
# 0   0.052648   0.499491   0.116978    0.67797   0.391005    0.15345   1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group KNO and output PEERW
#        KNO1      KNO2      KNO3      KNO4      KNO5  KNO1*KNO1  KNO1*KNO2  \
# 0  0.187733  0.067913 -0.123837  0.350929  0.332885   0.187733   0.067913
#
#    KNO1*KNO3  KNO1*KNO4  KNO1*KNO5  ...  KNO2*KNO3  KNO2*KNO4  KNO2*KNO5  \
# 0   0.054531   0.320795   0.279238  ...   0.067913        NaN   0.067913
#
#    KNO3*KNO3  KNO3*KNO4  KNO3*KNO5  KNO4*KNO4  KNO4*KNO5  KNO5*KNO5  PEERW
# 0  -0.172336   0.042313   -0.07459   0.312572   0.308316   0.338083    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group KNO and output PEERC
#        KNO1      KNO2      KNO3      KNO4      KNO5  KNO1*KNO1  KNO1*KNO2  \
# 0 -0.155309 -0.109231  0.107644  0.039677  0.241336  -0.155309  -0.109231
#
#    KNO1*KNO3  KNO1*KNO4  KNO1*KNO5  ...  KNO2*KNO3  KNO2*KNO4  KNO2*KNO5  \
# 0   0.007964  -0.134517   0.041692  ...  -0.109231        NaN  -0.109231
#
#    KNO3*KNO3  KNO3*KNO4  KNO3*KNO5  KNO4*KNO4  KNO4*KNO5  KNO5*KNO5  PEERC
# 0   0.119554  -0.193781    0.15746  -0.003429   0.036367   0.133447    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group KNO and output TASKM
#        KNO1      KNO2      KNO3     KNO4      KNO5  KNO1*KNO1  KNO1*KNO2  \
# 0  0.232737  0.045644  0.051406 -0.00349 -0.062059   0.232737   0.045644
#
#    KNO1*KNO3  KNO1*KNO4  KNO1*KNO5  ...  KNO2*KNO3  KNO2*KNO4  KNO2*KNO5  \
# 0   0.176677   0.079128   0.021293  ...   0.045644        NaN   0.045644
#
#    KNO3*KNO3  KNO3*KNO4  KNO3*KNO5  KNO4*KNO4  KNO4*KNO5  KNO5*KNO5  TASKM
# 0   0.143724  -0.211165  -0.021661  -0.031899  -0.071065  -0.093251    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group KNO and output TASKG
#        KNO1      KNO2      KNO3      KNO4      KNO5  KNO1*KNO1  KNO1*KNO2  \
# 0  0.256625 -0.079305  0.155243 -0.016678  0.219597   0.256625  -0.079305
#
#    KNO1*KNO3  KNO1*KNO4  KNO1*KNO5  ...  KNO2*KNO3  KNO2*KNO4  KNO2*KNO5  \
# 0   0.281744   0.055329   0.383415  ...  -0.079305        NaN  -0.079305
#
#    KNO3*KNO3  KNO3*KNO4  KNO3*KNO5  KNO4*KNO4  KNO4*KNO5  KNO5*KNO5  TASKG
# 0   0.229392  -0.053506   0.043282   0.015372   0.159391   0.273882    1.0
#
# [1 rows x 21 columns]
# The correlation dataframe between group BFX and output TA4
#        BFX1      BFX2      BFX3      BFX4      BFX5      BFX6      BFX7  \
# 0 -0.079333  0.186736  0.365148  0.162848  0.031903  0.111154 -0.187867
#
#        BFX8      BFX9     BFX10  ...  BFX12*BFX13  BFX12*BFX14  BFX12*BFX15  \
# 0 -0.096682  0.168364 -0.219823  ...    -0.216298    -0.331379    -0.167534
#
#    BFX13*BFX13  BFX13*BFX14  BFX13*BFX15  BFX14*BFX14  BFX14*BFX15  \
# 0     0.409786     0.216831     0.403769    -0.114035      0.04946
#
#    BFX15*BFX15  TA4
# 0     0.288095  1.0
#
# [1 rows x 136 columns]
# The correlation dataframe between group BFX and output TA5
#        BFX1      BFX2      BFX3      BFX4      BFX5      BFX6     BFX7  \
# 0 -0.046269 -0.263447  0.194444  0.053682  0.063101 -0.107811  0.25963
#
#        BFX8      BFX9     BFX10  ...  BFX12*BFX13  BFX12*BFX14  BFX12*BFX15  \
# 0  0.187831 -0.019212  0.122632  ...    -0.021491    -0.056125    -0.112538
#
#    BFX13*BFX13  BFX13*BFX14  BFX13*BFX15  BFX14*BFX14  BFX14*BFX15  \
# 0     0.050142    -0.040206    -0.093886    -0.093538    -0.230055
#
#    BFX15*BFX15  TA5
# 0    -0.137555  1.0
#
# [1 rows x 136 columns]
# The correlation dataframe between group BFX and output KNO6
#        BFX1      BFX2      BFX3      BFX4      BFX5      BFX6      BFX7  \
# 0  0.380319  0.304585  0.263863  0.183212  0.229414  0.461362 -0.015452
#
#        BFX8      BFX9     BFX10  ...  BFX12*BFX13  BFX12*BFX14  BFX12*BFX15  \
# 0  0.348141  0.236402 -0.095567  ...    -0.047614     0.199019     0.120116
#
#    BFX13*BFX13  BFX13*BFX14  BFX13*BFX15  BFX14*BFX14  BFX14*BFX15  \
# 0     0.058544     0.271812    -0.100166     0.403368     0.214945
#
#    BFX15*BFX15  KNO6
# 0    -0.007266   1.0
#
# [1 rows x 136 columns]
# The correlation dataframe between group BFX and output PEERW
#       BFX1      BFX2     BFX3      BFX4      BFX5      BFX6      BFX7  \
# 0  0.10024 -0.158769  0.18757 -0.056729  0.286508 -0.028057  0.270654
#
#        BFX8      BFX9     BFX10  ...  BFX12*BFX13  BFX12*BFX14  BFX12*BFX15  \
# 0  0.161242  0.092947  0.232327  ...    -0.066305     -0.09148    -0.155432
#
#    BFX13*BFX13  BFX13*BFX14  BFX13*BFX15  BFX14*BFX14  BFX14*BFX15  \
# 0     0.281434     0.156511     0.123608     0.049532    -0.049562
#
#    BFX15*BFX15  PEERW
# 0     0.045471    1.0
#
# [1 rows x 136 columns]
# The correlation dataframe between group BFX and output PEERC
#        BFX1      BFX2      BFX3      BFX4      BFX5     BFX6      BFX7  \
# 0  0.253138 -0.166312  0.184327  0.180649  0.331638  0.02286  0.441395
#
#        BFX8     BFX9     BFX10  ...  BFX12*BFX13  BFX12*BFX14  BFX12*BFX15  \
# 0  0.193551 -0.02833  0.386329  ...     0.513008     0.373137     0.365943
#
#    BFX13*BFX13  BFX13*BFX14  BFX13*BFX15  BFX14*BFX14  BFX14*BFX15  \
# 0    -0.128746      -0.1353     0.018232    -0.063776     0.030648
#
#    BFX15*BFX15  PEERC
# 0     0.059906    1.0
#
# [1 rows x 136 columns]
# The correlation dataframe between group BFX and output TASKM
#        BFX1      BFX2      BFX3      BFX4      BFX5      BFX6      BFX7  \
# 0  0.489219  0.517768  0.091287 -0.003393  0.394802  0.368198 -0.015656
#
#        BFX8      BFX9     BFX10  ...  BFX12*BFX13  BFX12*BFX14  BFX12*BFX15  \
# 0 -0.104119 -0.178887  0.233562  ...     0.355347     0.483001     0.445703
#
#    BFX13*BFX13  BFX13*BFX14  BFX13*BFX15  BFX14*BFX14  BFX14*BFX15  \
# 0    -0.217902    -0.145683     0.192362      0.25286     0.607656
#
#    BFX15*BFX15  TASKM
# 0     0.454394    1.0
#
# [1 rows x 136 columns]
# The correlation dataframe between group BFX and output TASKG
#       BFX1      BFX2      BFX3      BFX4      BFX5      BFX6      BFX7  \
# 0  0.32737  0.206469 -0.257742  0.050105  0.041574 -0.036212  0.010201
#
#        BFX8      BFX9     BFX10  ...  BFX12*BFX13  BFX12*BFX14  BFX12*BFX15  \
# 0 -0.061379 -0.344333  0.031828  ...     0.034514     0.301464     0.090622
#
#    BFX13*BFX13  BFX13*BFX14  BFX13*BFX15  BFX14*BFX14  BFX14*BFX15  \
# 0    -0.111132     0.076526    -0.226678     0.212133     0.095144
#
#    BFX15*BFX15  TASKG
# 0    -0.209585    1.0
#
# [1 rows x 136 columns]
# The correlation dataframe between group WEIP and output TA4
#       WEIP1     WEIP2     WEIP3    WEIP4     WEIP5     WEIP6     WEIP7  \
# 0 -0.124568  0.112739 -0.211018 -0.01992 -0.202038 -0.198151 -0.024845
#
#       WEIP8     WEIP9    WEIP10  ...  WEIP13*WEIP14  WEIP13*WEIP15  \
# 0 -0.087333  0.465285  0.187507  ...        0.33956       0.289886
#
#    WEIP13*WEIP16  WEIP14*WEIP14  WEIP14*WEIP15  WEIP14*WEIP16  WEIP15*WEIP15  \
# 0       0.104389       0.462293       0.365986       0.016408       0.021277
#
#    WEIP15*WEIP16  WEIP16*WEIP16  TA4
# 0       0.041665      -0.052687  1.0
#
# [1 rows x 153 columns]
# The correlation dataframe between group WEIP and output TA5
#       WEIP1     WEIP2     WEIP3     WEIP4     WEIP5     WEIP6    WEIP7  \
# 0  0.337985  0.090441  0.134005  0.354604  0.423114  0.361773 -0.01134
#
#       WEIP8     WEIP9    WEIP10  ...  WEIP13*WEIP14  WEIP13*WEIP15  \
# 0  0.115157 -0.042032  0.060991  ...       0.323586      -0.198471
#
#    WEIP13*WEIP16  WEIP14*WEIP14  WEIP14*WEIP15  WEIP14*WEIP16  WEIP15*WEIP15  \
# 0       -0.09605       0.242764       0.043309       0.103184      -0.211498
#
#    WEIP15*WEIP16  WEIP16*WEIP16  TA5
# 0      -0.128273       0.001002  1.0
#
# [1 rows x 153 columns]
# The correlation dataframe between group WEIP and output KNO6
#       WEIP1     WEIP2   WEIP3     WEIP4     WEIP5     WEIP6     WEIP7  \
# 0  0.187349  0.276014 -0.0912  0.271046  0.072056  0.321299  0.000876
#
#       WEIP8     WEIP9    WEIP10  ...  WEIP13*WEIP14  WEIP13*WEIP15  \
# 0  0.110825  0.127109  0.306775  ...       0.262897       0.408736
#
#    WEIP13*WEIP16  WEIP14*WEIP14  WEIP14*WEIP15  WEIP14*WEIP16  WEIP15*WEIP15  \
# 0       0.277552       0.166554       0.259452       0.196069       0.258005
#
#    WEIP15*WEIP16  WEIP16*WEIP16  KNO6
# 0       0.034384      -0.027162   1.0
#
# [1 rows x 153 columns]
# The correlation dataframe between group WEIP and output PEERW
#       WEIP1     WEIP2    WEIP3     WEIP4     WEIP5     WEIP6     WEIP7  \
# 0  0.330238  0.220029  0.25092  0.278049  0.079153  0.107051  0.025525
#
#       WEIP8    WEIP9    WEIP10  ...  WEIP13*WEIP14  WEIP13*WEIP15  \
# 0  0.239261  0.42084  0.065052  ...       0.513012       0.369704
#
#    WEIP13*WEIP16  WEIP14*WEIP14  WEIP14*WEIP15  WEIP14*WEIP16  WEIP15*WEIP15  \
# 0       0.376149       0.521663       0.412736        0.46366       0.291792
#
#    WEIP15*WEIP16  WEIP16*WEIP16  PEERW
# 0       0.355288       0.322441    1.0
#
# [1 rows x 153 columns]
# The correlation dataframe between group WEIP and output PEERC
#       WEIP1     WEIP2     WEIP3    WEIP4     WEIP5     WEIP6     WEIP7  \
# 0  0.226686  0.248338  0.334833  0.18771  0.223975  0.440859  0.122632
#
#       WEIP8     WEIP9    WEIP10  ...  WEIP13*WEIP14  WEIP13*WEIP15  \
# 0  0.006531  0.237051  0.210825  ...       0.142633       0.140915
#
#    WEIP13*WEIP16  WEIP14*WEIP14  WEIP14*WEIP15  WEIP14*WEIP16  WEIP15*WEIP15  \
# 0       0.081413       0.132509       0.304622       0.315766       0.333448
#
#    WEIP15*WEIP16  WEIP16*WEIP16  PEERC
# 0       0.204917        0.18002    1.0
#
# [1 rows x 153 columns]
# The correlation dataframe between group WEIP and output TASKM
#       WEIP1     WEIP2     WEIP3     WEIP4     WEIP5     WEIP6     WEIP7  \
# 0  0.197233  0.312595  0.330289  0.039841 -0.457556 -0.253881 -0.229818
#
#       WEIP8     WEIP9    WEIP10  ...  WEIP13*WEIP14  WEIP13*WEIP15  \
# 0 -0.116445 -0.076336 -0.245699  ...      -0.369043       0.028989
#
#    WEIP13*WEIP16  WEIP14*WEIP14  WEIP14*WEIP15  WEIP14*WEIP16  WEIP15*WEIP15  \
# 0       0.213748      -0.279076      -0.155883      -0.073836       0.377078
#
#    WEIP15*WEIP16  WEIP16*WEIP16  TASKM
# 0       0.425225       0.372929    1.0
#
# [1 rows x 153 columns]
# The correlation dataframe between group WEIP and output TASKG
#       WEIP1     WEIP2     WEIP3     WEIP4     WEIP5     WEIP6     WEIP7  \
# 0  0.401308  0.302728  0.143468  0.190364 -0.108409 -0.016138  0.345346
#
#       WEIP8     WEIP9    WEIP10  ...  WEIP13*WEIP14  WEIP13*WEIP15  \
# 0  0.139096  0.353687 -0.345451  ...      -0.065357      -0.232949
#
#    WEIP13*WEIP16  WEIP14*WEIP14  WEIP14*WEIP15  WEIP14*WEIP16  WEIP15*WEIP15  \
# 0      -0.106881        -0.0591      -0.089791      -0.073647      -0.054426
#
#    WEIP15*WEIP16  WEIP16*WEIP16  TASKG
# 0       0.038325       0.027892    1.0
#
# [1 rows x 153 columns]
# The correlation dataframe between group PEER and output TA4
#       PEER1     PEER2     PEER3     PEER4     PEER5     PEER6  PEER1*PEER1  \
# 0  0.203059  0.042945 -0.074307 -0.192345  0.044821  0.096449     0.280747
#
#    PEER1*PEER2  PEER1*PEER3  PEER1*PEER4  ...  PEER3*PEER4  PEER3*PEER5  \
# 0     0.286039    -0.050375    -0.037396  ...    -0.256278    -0.124484
#
#    PEER3*PEER6  PEER4*PEER4  PEER4*PEER5  PEER4*PEER6  PEER5*PEER5  \
# 0     0.091287    -0.256579    -0.176475    -0.124568    -0.007157
#
#    PEER5*PEER6  PEER6*PEER6  TA4
# 0     0.093911     0.105409  1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group PEER and output TA5
#      PEER1     PEER2     PEER3     PEER4     PEER5     PEER6  PEER1*PEER1  \
# 0 -0.25631  0.117609 -0.015074  0.016723  0.100017  0.282478    -0.281684
#
#    PEER1*PEER2  PEER1*PEER3  PEER1*PEER4  ...  PEER3*PEER4  PEER3*PEER5  \
# 0    -0.130558    -0.265694    -0.197242  ...    -0.149467    -0.068656
#
#    PEER3*PEER6  PEER4*PEER4  PEER4*PEER5  PEER4*PEER6  PEER5*PEER5  \
# 0     0.018519    -0.014036     -0.08055     0.022111    -0.008712
#
#    PEER5*PEER6  PEER6*PEER6  TA5
# 0     0.127294     0.248581  1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group PEER and output KNO6
#       PEER1     PEER2     PEER3     PEER4     PEER5     PEER6  PEER1*PEER1  \
# 0  0.253969  0.091837 -0.049766  0.305428  0.396036 -0.050147     0.240185
#
#    PEER1*PEER2  PEER1*PEER3  PEER1*PEER4  ...  PEER3*PEER4  PEER3*PEER5  \
# 0     0.447004    -0.107725     0.205641  ...     0.240523     0.146999
#
#    PEER3*PEER6  PEER4*PEER4  PEER4*PEER5  PEER4*PEER6  PEER5*PEER5  \
# 0    -0.180199     0.192472     0.278377     0.105018     0.412762
#
#    PEER5*PEER6  PEER6*PEER6  KNO6
# 0     0.085467    -0.087318   1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group PEER and output PEERW
#       PEER1     PEER2     PEER3     PEER4     PEER5     PEER6  PEER1*PEER1  \
# 0  0.328243 -0.137938  0.085114  0.303064  0.321803 -0.158882     0.365218
#
#    PEER1*PEER2  PEER1*PEER3  PEER1*PEER4  ...  PEER3*PEER4  PEER3*PEER5  \
# 0    -0.077689     0.181631     0.362998  ...     0.248159     0.177503
#
#    PEER3*PEER6  PEER4*PEER4  PEER4*PEER5  PEER4*PEER6  PEER5*PEER5  \
# 0    -0.056055     0.278408     0.337601     0.017652     0.416857
#
#    PEER5*PEER6  PEER6*PEER6  PEERW
# 0    -0.034479    -0.182979    1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group PEER and output PEERC
#       PEER1     PEER2     PEER3     PEER4     PEER5     PEER6  PEER1*PEER1  \
# 0 -0.181105 -0.201263  0.209315  0.298651  0.147486  0.326385    -0.197852
#
#    PEER1*PEER2  PEER1*PEER3  PEER1*PEER4  ...  PEER3*PEER4  PEER3*PEER5  \
# 0    -0.263828    -0.015069    -0.182096  ...      0.21881     0.131498
#
#    PEER3*PEER6  PEER4*PEER4  PEER4*PEER5  PEER4*PEER6  PEER5*PEER5  \
# 0     0.095577     0.194902     0.087435     0.304318     0.040681
#
#    PEER5*PEER6  PEER6*PEER6  PEERC
# 0      0.18771     0.287732    1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group PEER and output TASKM
#       PEER1     PEER2     PEER3     PEER4     PEER5     PEER6  PEER1*PEER1  \
# 0  0.176737 -0.300614  0.086691  0.247301  0.022411  0.138645     0.178313
#
#    PEER1*PEER2  PEER1*PEER3  PEER1*PEER4  ...  PEER3*PEER4  PEER3*PEER5  \
# 0    -0.214529     0.240678     0.334489  ...     0.138817     0.015561
#
#    PEER3*PEER6  PEER4*PEER4  PEER4*PEER5  PEER4*PEER6  PEER5*PEER5  \
# 0     0.091287     0.181623     0.215079      0.08045    -0.039366
#
#    PEER5*PEER6  PEER6*PEER6  TASKM
# 0    -0.038418     0.223995    1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group PEER and output TASKG
#      PEER1     PEER2     PEER3     PEER4     PEER5     PEER6  PEER1*PEER1  \
# 0  0.26461  0.149232 -0.043036  0.206884 -0.038938  0.125684     0.277956
#
#    PEER1*PEER2  PEER1*PEER3  PEER1*PEER4  ...  PEER3*PEER4  PEER3*PEER5  \
# 0     0.020708     0.189638     0.267122  ...     0.037107    -0.162218
#
#    PEER3*PEER6  PEER4*PEER4  PEER4*PEER5  PEER4*PEER6  PEER5*PEER5  \
# 0     0.066088     0.222902     0.213199     0.130763     0.037308
#
#    PEER5*PEER6  PEER6*PEER6  TASKG
# 0    -0.081585     0.137361    1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group TASK and output TA4
#       TASK1     TASK2     TASK3     TASK4     TASK5     TASK6  TASK1*TASK1  \
# 0 -0.214491 -0.047673  0.099472 -0.137812 -0.451803  0.265936    -0.206898
#
#    TASK1*TASK2  TASK1*TASK3  TASK1*TASK4  ...  TASK3*TASK4  TASK3*TASK5  \
# 0    -0.245658    -0.217407    -0.101173  ...     -0.18093    -0.400549
#
#    TASK3*TASK6  TASK4*TASK4  TASK4*TASK5  TASK4*TASK6  TASK5*TASK5  \
# 0     0.258199    -0.210915    -0.328022     0.012529    -0.412861
#
#    TASK5*TASK6  TASK6*TASK6  TA4
# 0    -0.264658     0.272474  1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group TASK and output TA5
#       TASK1     TASK2     TASK3     TASK4     TASK5     TASK6  TASK1*TASK1  \
# 0  0.554774  0.174078 -0.193251  0.026958  0.303403 -0.098513     0.482671
#
#    TASK1*TASK2  TASK1*TASK3  TASK1*TASK4  ...  TASK3*TASK4  TASK3*TASK5  \
# 0     0.323922     0.210492      0.21818  ...    -0.120653     0.181966
#
#    TASK3*TASK6  TASK4*TASK4  TASK4*TASK5  TASK4*TASK6  TASK5*TASK5  \
# 0    -0.117851     0.127387     0.147597    -0.041938     0.234509
#
#    TASK5*TASK6  TASK6*TASK6  TA5
# 0     0.262381    -0.184851  1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group TASK and output KNO6
#       TASK1     TASK2     TASK3     TASK4     TASK5     TASK6  TASK1*TASK1  \
# 0 -0.011341  0.255431  0.127308 -0.244974 -0.247676  0.204602     0.030253
#
#    TASK1*TASK2  TASK1*TASK3  TASK1*TASK4  ...  TASK3*TASK4  TASK3*TASK5  \
# 0     0.103271     0.055735    -0.060783  ...    -0.115071    -0.075369
#
#    TASK3*TASK6  TASK4*TASK4  TASK4*TASK5  TASK4*TASK6  TASK5*TASK5  \
# 0     0.168377    -0.253907    -0.329168    -0.055649    -0.181431
#
#    TASK5*TASK6  TASK6*TASK6  KNO6
# 0    -0.190796      0.21634   1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group TASK and output PEERW
#      TASK1   TASK2     TASK3     TASK4     TASK5     TASK6  TASK1*TASK1  \
# 0  0.01773  0.0304  0.064515 -0.130424  0.149571  0.126161    -0.014116
#
#    TASK1*TASK2  TASK1*TASK3  TASK1*TASK4  ...  TASK3*TASK4  TASK3*TASK5  \
# 0     0.028364    -0.140035    -0.088514  ...    -0.196654     0.051763
#
#    TASK3*TASK6  TASK4*TASK4  TASK4*TASK5  TASK4*TASK6  TASK5*TASK5  \
# 0     0.105191    -0.143325    -0.000494    -0.212614     0.084832
#
#    TASK5*TASK6  TASK6*TASK6  PEERW
# 0     0.185702    -0.016457    1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group TASK and output PEERC
#       TASK1    TASK2     TASK3     TASK4     TASK5     TASK6  TASK1*TASK1  \
# 0  0.016041  0.14974  0.315872  0.076561  0.156125 -0.102035    -0.004585
#
#    TASK1*TASK2  TASK1*TASK3  TASK1*TASK4  ...  TASK3*TASK4  TASK3*TASK5  \
# 0     0.035382     0.118246    -0.221067  ...     0.210737     0.289426
#
#    TASK3*TASK6  TASK4*TASK4  TASK4*TASK5  TASK4*TASK6  TASK5*TASK5  \
# 0     0.236541       0.1042     0.021922    -0.014992     0.222307
#
#    TASK5*TASK6  TASK6*TASK6  PEERC
# 0     -0.18771    -0.155667    1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group TASK and output TASKM
#       TASK1     TASK2     TASK3     TASK4     TASK5     TASK6  TASK1*TASK1  \
# 0  0.138525  0.405222  0.547094  0.275625  0.319378 -0.127187      0.25096
#
#    TASK1*TASK2  TASK1*TASK3  TASK1*TASK4  ...  TASK3*TASK4  TASK3*TASK5  \
# 0     0.354839     0.296464      0.26833  ...     0.621706     0.413242
#
#    TASK3*TASK6  TASK4*TASK4  TASK4*TASK5  TASK4*TASK6  TASK5*TASK5  \
# 0      0.06455     0.278025     0.333257    -0.134691     0.357813
#
#    TASK5*TASK6  TASK6*TASK6  TASKM
# 0    -0.068299    -0.098269    1.0
#
# [1 rows x 28 columns]
# The correlation dataframe between group TASK and output TASKG
#      TASK1     TASK2    TASK3     TASK4     TASK5     TASK6  TASK1*TASK1  \
# 0  0.36103  0.559113  0.06315  0.247999  0.561683 -0.130582     0.371133
#
#    TASK1*TASK2  TASK1*TASK3  TASK1*TASK4  ...  TASK3*TASK4  TASK3*TASK5  \
# 0     0.549343     0.197456     0.403165  ...     0.198986     0.476627
#
#    TASK3*TASK6  TASK4*TASK4  TASK4*TASK5  TASK4*TASK6  TASK5*TASK5  \
# 0    -0.448618     0.238756     0.497177    -0.187764     0.549962
#
#    TASK5*TASK6  TASK6*TASK6  TASKG
# 0     0.100126     0.015522    1.0
#
# [1 rows x 28 columns]
